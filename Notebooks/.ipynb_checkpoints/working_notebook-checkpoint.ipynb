# %% [markdown]
# # Image Classification Using Neural Networks

# %% [markdown]
# ## Project Name

# %% [markdown]
# ### Overview
#
# For the fourth phase, I put everything I've learned together to build a deep neural network that trains on a large dataset for classification on a non-trivial task. In this case, using x-ray images of pediatric patients to identify whether or not they have pneumonia. The dataset comes from [Kermany et al. on Mendeley](https://data.mendeley.com/datasets/rscbjbr9sj/3)
#
#
# The images are split into a training set and a testing set of independent patients. Images are labeled as (disease)-(randomized patient ID)-(image number by this patient)
#
# **Key facts**
# - Pneumonia accounts for 14% of all deaths of children under 5 years old, killing 740 180 children in 2019
# - Pneumonia can be caused by viruses, bacteria, or fungi.
# - Pneumonia can be prevented by immunization, adequate nutrition, and by addressing environmental factors.
# - Pneumonia caused by bacteria can be treated with antibiotics, but only one third of children with pneumonia receive the antibiotics they need.
# - Pneumonia is a form of acute respiratory infection that affects the lungs. The lungs are made up of small sacs called alveoli, which fill with air when a healthy person breathes. When an individual has pneumonia, the alveoli are filled with pus and fluid, which makes breathing painful and limits oxygen intake.
#
# **Pneumonia is the single largest infectious cause of death in children worldwide.** Pneumonia killed 740 180 children under the age of 5 in 2019, accounting for 14% of all deaths of children under five years old but 22% of all deaths in children aged 1 to 5. Pneumonia affects children and families everywhere, but deaths are highest in South Asia and sub-Saharan Africa. Children can be protected from pneumonia, it can be prevented with simple interventions, and treated with low-cost, low-tech medication and care.

# %% [markdown]
# ## Business Area
#
# Rural Hospitals and population-dense hospitals in Sri Lankajust recieved a large grant from the Bill and Melinda Gates foundation to purchase X Ray Machines for their practices. One of the largest problems present in these areas is the prevalence of pneumonia in their pediatric population, and the level of lethality it has for those children

# %% [markdown]
# ## Problem
#
# The Gates Foundation has the capital to provide the doctors with XRay Machines, but doctors have been widely complaining and criticizing the effort due to the huge volume of patients they see every day. The doctors don't have time to review all of the Xrays, and they don't have enough funding to high radiology techs.
#
#
#
# In order to solve this issue, the Gates foundation called on us to build a model that can take in the Xray scans of a patient and automatically predict whether that pediatric patient has pneumonia. The Gates foundation envisions this becoming an automated process in which the xray machine atomatically uploads the image as a jpeg to be run through the model, and depending on the result automatically send the patient's family a notification and a prescription for antibiotics if needed.

# %% [markdown]
# # Imports

# %%
import os
import sys
module_path = os.path.abspath(os.path.join(os.pardir, os.pardir))
if module_path not in sys.path:
    sys.path.append(module_path)

import tensorflow as tf
import numpy as np
from matplotlib import pyplot as plt
import matplotlib.image as mpimg
from sklearn.model_selection import train_test_split, cross_val_score
from tensorflow import keras
from tensorflow.keras import datasets, layers, models
from tensorflow.keras.regularizers import l2

from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
    
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Data Review

# %% [markdown]
# Using loading process outlined in
#
# https://github.com/nicknochnack/ImageClassification/blob/main/Getting%20Started.ipynb

# %%
# Avoid OOM errors by setting GPU Memory Consumption Growth
gpus = tf.config.experimental.list_physical_devices('GPU')
for gpu in gpus: 
    tf.config.experimental.set_memory_growth(gpu, True)

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# # Data Preparation

# %%
train_data = tf.keras.utils.image_dataset_from_directory('../Data/CellData/chest_xray/train/',
                                                        color_mode='grayscale',
                                                        label_mode='binary')
# Out:
# Found 3871 files belonging to 2 classes.
# Metal device set to: Apple M1 Pro
# 2022-09-14 13:41:01.567195: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2022-09-14 13:41:01.567332: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
val_data = tf.keras.utils.image_dataset_from_directory('../Data/CellData/chest_xray/validation/',
                                                       color_mode='grayscale',
                                                       label_mode='binary')
# Out:
# Found 1361 files belonging to 2 classes.

# %%
test_data = tf.keras.utils.image_dataset_from_directory('../Data/CellData/chest_xray/test/',
                                                        color_mode='grayscale',
                                                       label_mode='binary')
# Out:
# Found 624 files belonging to 2 classes.

# %%
data_iterator = train_data.as_numpy_iterator()

# %%
batch = data_iterator.next()
# Out:
# 2022-09-14 13:41:01.789961: W tensorflow/core/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz

# %%
fig, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx, img in enumerate(batch[0][:4]):
    ax[idx].imshow(img.astype(int))
    ax[idx].title.set_text(batch[1][idx])

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Scaling Data First

# %%
train_data = train_data.map(lambda x,y: (x/255, y))
test_data = test_data.map(lambda x,y: (x/255, y))
val_data = val_data.map(lambda x,y: (x/255, y))

# %%
train_data
# Out:
# <MapDataset element_spec=(TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
test_data
# Out:
# <MapDataset element_spec=(TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
val_data
# Out:
# <MapDataset element_spec=(TensorSpec(shape=(None, 256, 256, 1), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %% [markdown]
# # Modeling

# %% [markdown]
# ### TensorFlow with and without transfer learning

# %%
# Re-importing libraries to be safe
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Flatten, Dropout

# %%
model = Sequential()

# %%
model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,1)))
model.add(MaxPooling2D())
model.add(Conv2D(32, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Conv2D(16, (3,3), 1, activation='relu'))
model.add(MaxPooling2D())
model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 254, 254, 16)      160
#
#  max_pooling2d (MaxPooling2D  (None, 127, 127, 16)     0
#  )
#
#  conv2d_1 (Conv2D)           (None, 125, 125, 32)      4640
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 16)        4624
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 16)       0
#  2D)
#
#  flatten (Flatten)           (None, 14400)             0
#
#  dense (Dense)               (None, 256)               3686656
#
#  dense_1 (Dense)             (None, 1)                 257
#
# =================================================================
# Total params: 3,696,337
# Trainable params: 3,696,337
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Train Model

# %%
logdir='logs'

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=logdir)

# %% [markdown]
# Check Training Performance

# %%
hist = model.fit(train_data, epochs=20, validation_data=val_data, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 2022-09-14 13:41:03.141800: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - ETA: 0s - loss: 0.2766 - accuracy: 0.8858
# 2022-09-14 13:41:10.446543: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - 9s 69ms/step - loss: 0.2766 - accuracy: 0.8858 - val_loss: 0.1612 - val_accuracy: 0.9339
# Epoch 2/20
# 121/121 [==============================] - 9s 67ms/step - loss: 0.1135 - accuracy: 0.9571 - val_loss: 0.1596 - val_accuracy: 0.9361
# Epoch 3/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0901 - accuracy: 0.9662 - val_loss: 0.1296 - val_accuracy: 0.9471
# Epoch 4/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0756 - accuracy: 0.9734 - val_loss: 0.1059 - val_accuracy: 0.9581
# Epoch 5/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0583 - accuracy: 0.9786 - val_loss: 0.0979 - val_accuracy: 0.9633
# Epoch 6/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0509 - accuracy: 0.9817 - val_loss: 0.2040 - val_accuracy: 0.9324
# Epoch 7/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0382 - accuracy: 0.9889 - val_loss: 0.1036 - val_accuracy: 0.9625
# Epoch 8/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0340 - accuracy: 0.9868 - val_loss: 0.1831 - val_accuracy: 0.9353
# Epoch 9/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0285 - accuracy: 0.9892 - val_loss: 0.1016 - val_accuracy: 0.9633
# Epoch 10/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0259 - accuracy: 0.9920 - val_loss: 0.1172 - val_accuracy: 0.9655
# Epoch 11/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0175 - accuracy: 0.9941 - val_loss: 0.1341 - val_accuracy: 0.9633
# Epoch 12/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0130 - accuracy: 0.9951 - val_loss: 0.1250 - val_accuracy: 0.9640
# Epoch 13/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0043 - accuracy: 0.9992 - val_loss: 0.1355 - val_accuracy: 0.9655
# Epoch 14/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.1808 - val_accuracy: 0.9566
# Epoch 15/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0115 - accuracy: 0.9954 - val_loss: 0.1387 - val_accuracy: 0.9655
# Epoch 16/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0272 - accuracy: 0.9904 - val_loss: 0.1358 - val_accuracy: 0.9552
# Epoch 17/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0134 - accuracy: 0.9964 - val_loss: 0.1204 - val_accuracy: 0.9640
# Epoch 18/20
# 121/121 [==============================] - 9s 69ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.1373 - val_accuracy: 0.9684
# Epoch 19/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0048 - accuracy: 0.9985 - val_loss: 0.1828 - val_accuracy: 0.9640
# Epoch 20/20
# 121/121 [==============================] - 9s 68ms/step - loss: 8.3366e-04 - accuracy: 1.0000 - val_loss: 0.1841 - val_accuracy: 0.9662

# %% [markdown]
# # Initial Model Performance

# %% [markdown]
# ### Model Explainability
#
# Lime - https://christophm.github.io/interpretable-ml-book/lime.html

# %% [markdown]
# Now that we have an initial model that has been fitted and trained, and we have a validation dataset to check if there is overfitting, let's see how it performed

# %%
sigmoid_loss = hist.history['loss']
sigmoid_accuracy = hist.history['accuracy']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 5))
sns.lineplot(x=hist.epoch, y=sigmoid_loss, ax=ax1, label='loss')
sns.lineplot(x=hist.epoch, y=sigmoid_accuracy, ax=ax2, label='accuracy')
plt.suptitle('Loss and Accuracy for the Training Data Set', fontsize=20)
ax1.set_xlabel('Number of Epochs', loc='center', fontsize=12)
ax2.set_xlabel('Number of Epochs', loc='center', fontsize=12);

# %% [markdown]
# Now that we can see our model is performing well at generating a high level of accuracy and low level of loss, how does the model perform with regards to validation data to make sure it isn't overfitting (as CNNs tend to)

# %%
sigmoid_loss = hist.history['loss']
sigmoid_accuracy = hist.history['accuracy']
val_sigmoid_loss = hist.history['val_loss']
val_sigmoid_accuracy = hist.history['val_accuracy']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
sns.lineplot(x=hist.epoch, y=sigmoid_loss, ax=ax1, label='loss')
sns.lineplot(x=hist.epoch, y=sigmoid_accuracy, ax=ax2, label='accuracy')
sns.lineplot(x=hist.epoch, y=val_sigmoid_loss, ax=ax1, label='loss')
sns.lineplot(x=hist.epoch, y=val_sigmoid_accuracy, ax=ax2, label='accuracy')
plt.suptitle('Loss and Accuracy for the Training Data Set', fontsize=20)
ax1.set_xlabel('Number of Epochs', loc='center', fontsize=12)
ax2.set_xlabel('Number of Epochs', loc='center', fontsize=12);

# %% [markdown]
# It looks like our model needs to be better tuned in order to reduce the variability in loss that is occuring in the validation dataset, and to try and reduce the amount of overfitting occuring in the current model (leading to the lower level of accuracy on the validation dataset)

# %% [markdown]
# # Model Tuning

# %% [markdown]
# ## Epoch and Batch Tuning

# %% [markdown]
# Since both our training datasets loss and accuracy leveled out, our model is likely no longer learning. with that said, our validataion loss and accuracy isn't performing as well as wel would like.
#
#
# let's see if that is true - we will increase the number of epochs by 50% (to 30) and decrease batch sizeby around 50% (to 15 from 32)

# %%
model2 = Sequential()

model2.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,1)))
model2.add(MaxPooling2D())
model2.add(Conv2D(32, (3,3), 1, activation='relu'))
model2.add(MaxPooling2D())
model2.add(Conv2D(16, (3,3), 1, activation='relu'))
model2.add(MaxPooling2D())
model2.add(Flatten())
model2.add(Dense(256, activation='relu'))
model2.add(Dense(1, activation='sigmoid'))

model2.compile('adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
hist2 = model2.fit(train_data, epochs=30, batch_size=15, validation_data=val_data, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/30
# 2022-09-14 13:43:55.410789: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - ETA: 0s - loss: 0.2378 - accuracy: 0.9005
# 2022-09-14 13:44:02.643474: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - 9s 69ms/step - loss: 0.2378 - accuracy: 0.9005 - val_loss: 0.1536 - val_accuracy: 0.9405
# Epoch 2/30
# 121/121 [==============================] - 9s 69ms/step - loss: 0.0979 - accuracy: 0.9667 - val_loss: 0.1368 - val_accuracy: 0.9427
# Epoch 3/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0857 - accuracy: 0.9718 - val_loss: 0.1178 - val_accuracy: 0.9530
# Epoch 4/30
# 121/121 [==============================] - 8s 67ms/step - loss: 0.0590 - accuracy: 0.9793 - val_loss: 0.1030 - val_accuracy: 0.9611
# Epoch 5/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0550 - accuracy: 0.9801 - val_loss: 0.1420 - val_accuracy: 0.9493
# Epoch 6/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0386 - accuracy: 0.9858 - val_loss: 0.1935 - val_accuracy: 0.9368
# Epoch 7/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0304 - accuracy: 0.9881 - val_loss: 0.1652 - val_accuracy: 0.9486
# Epoch 8/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0190 - accuracy: 0.9925 - val_loss: 0.1181 - val_accuracy: 0.9647
# Epoch 9/30
# 121/121 [==============================] - 9s 69ms/step - loss: 0.0220 - accuracy: 0.9917 - val_loss: 0.1790 - val_accuracy: 0.9515
# Epoch 10/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0191 - accuracy: 0.9938 - val_loss: 0.1354 - val_accuracy: 0.9625
# Epoch 11/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.1423 - val_accuracy: 0.9596
# Epoch 12/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0027 - accuracy: 0.9997 - val_loss: 0.1400 - val_accuracy: 0.9691
# Epoch 13/30
# 121/121 [==============================] - 8s 67ms/step - loss: 0.0015 - accuracy: 0.9997 - val_loss: 0.1677 - val_accuracy: 0.9603
# Epoch 14/30
# 121/121 [==============================] - 8s 67ms/step - loss: 6.5566e-04 - accuracy: 1.0000 - val_loss: 0.1711 - val_accuracy: 0.9669
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
sns.lineplot(x=hist2.epoch, y=sigmoid_loss, ax=ax1, label='loss')
sns.lineplot(x=hist2.epoch, y=sigmoid_accuracy, ax=ax2, label='accuracy')
sns.lineplot(x=hist2.epoch, y=val_sigmoid_loss, ax=ax1, label='val_loss')
sns.lineplot(x=hist2.epoch, y=val_sigmoid_accuracy, ax=ax2, label='val_accuracy')
plt.suptitle('Loss and Accuracy for After Tuning Epochs and Batch Size', fontsize=20)
ax1.set_title('Model Loss after increasing Epochs by 50% \n and decreasing Batch Size by 50%', fontsize=12)
ax2.set_title('Model Accuracy after increasing Epochs by 50% \n and decreasing Batch Size by 50%', fontsize=12)
ax1.set_xlabel('Number of Epochs', loc='center', fontsize=12)
ax2.set_xlabel('Number of Epochs', loc='center', fontsize=12);

# %% [markdown]
# It looks like changing batch size and epochs did in fact improve accuracy (validation accuracy sitting at 96% instead of 95%), but changing batch size and epochs lead to worse performance on model loss for validation...
#
#
# To try and improve loss, let's change the learning rate to account for the change in epochs and batch size, shrinking it by 50%

# %% [markdown]
# ## Reducing learning rate to avoid missing the min learning rate

# %%
model3 = Sequential()

model3.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,1)))
model3.add(MaxPooling2D())
model3.add(Conv2D(32, (3,3), 1, activation='relu'))
model3.add(MaxPooling2D())
model3.add(Conv2D(16, (3,3), 1, activation='relu'))
model3.add(MaxPooling2D())
model3.add(Flatten())
model3.add(Dense(256, activation='relu'))
model3.add(Dense(1, activation='sigmoid'))

adam = tf.keras.optimizers.Adam(learning_rate=0.0005)

model3.compile(optimizer=adam, loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
hist3 = model3.fit(train_data, epochs=30, batch_size=15, validation_data=val_data, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/30
# 2022-09-14 13:48:12.739896: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - ETA: 0s - loss: 0.2663 - accuracy: 0.8861
# 2022-09-14 13:48:20.021774: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - 9s 69ms/step - loss: 0.2663 - accuracy: 0.8861 - val_loss: 0.1598 - val_accuracy: 0.9361
# Epoch 2/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0942 - accuracy: 0.9687 - val_loss: 0.1468 - val_accuracy: 0.9456
# Epoch 3/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0753 - accuracy: 0.9737 - val_loss: 0.1156 - val_accuracy: 0.9552
# Epoch 4/30
# 121/121 [==============================] - 8s 67ms/step - loss: 0.0725 - accuracy: 0.9747 - val_loss: 0.1717 - val_accuracy: 0.9324
# Epoch 5/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0505 - accuracy: 0.9837 - val_loss: 0.1182 - val_accuracy: 0.9589
# Epoch 6/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0420 - accuracy: 0.9853 - val_loss: 0.1065 - val_accuracy: 0.9559
# Epoch 7/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0392 - accuracy: 0.9858 - val_loss: 0.1328 - val_accuracy: 0.9522
# Epoch 8/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0296 - accuracy: 0.9894 - val_loss: 0.1517 - val_accuracy: 0.9493
# Epoch 9/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0204 - accuracy: 0.9935 - val_loss: 0.1365 - val_accuracy: 0.9544
# Epoch 10/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0226 - accuracy: 0.9923 - val_loss: 0.1318 - val_accuracy: 0.9625
# Epoch 11/30
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0239 - accuracy: 0.9917 - val_loss: 0.1337 - val_accuracy: 0.9625
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
sns.lineplot(x=hist3.epoch, y=sigmoid_loss, ax=ax1, label='loss')
sns.lineplot(x=hist3.epoch, y=sigmoid_accuracy, ax=ax2, label='accuracy')
sns.lineplot(x=hist3.epoch, y=val_sigmoid_loss, ax=ax1, label='val_loss')
sns.lineplot(x=hist3.epoch, y=val_sigmoid_accuracy, ax=ax2, label='val_accuracy')
plt.suptitle('Loss and Accuracy After shrinking learning rate by 50%', fontsize=20)
ax1.set_title('Model Loss after decreasing learning rate by 50%', fontsize=12)
ax2.set_title('Model Accuracy after decreasing learning rate by 50%', fontsize=12)
ax1.set_xlabel('Number of Epochs', loc='center', fontsize=12)
ax2.set_xlabel('Number of Epochs', loc='center', fontsize=12);

# %% [markdown]
# I'm pretty happy with the change in the model loss and accuracy due to the reduced learning rate, but it seems now the # of epohcs isn't necessary. I'm going to introduce a different stopping function (from lab on regularization). To avoid too early of stopping, I'm going to use patience=5

# %% [markdown]
# ## Adding Early Stopping Term

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Define the EarlyStopping object
early_stop = EarlyStopping(monitor='val_loss', min_delta=1e-10,
                           verbose=1,
                           mode='min',
                           patience=5)

# %%
model4 = Sequential()

model4.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,1)))
model4.add(MaxPooling2D())
model4.add(Conv2D(32, (3,3), 1, activation='relu'))
model4.add(MaxPooling2D())
model4.add(Conv2D(16, (3,3), 1, activation='relu'))
model4.add(MaxPooling2D())
model4.add(Flatten())
model4.add(Dense(256, activation='relu'))
model4.add(Dense(1, activation='sigmoid'))

adam = tf.keras.optimizers.Adam(learning_rate=0.0005)

model4.compile(optimizer=adam, loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
hist4 = model4.fit(train_data, epochs=20, batch_size=15, validation_data=val_data, callbacks=[early_stop])
# Out:
# Epoch 1/20
# 2022-09-14 13:52:30.111304: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - ETA: 0s - loss: 0.2406 - accuracy: 0.9018
# 2022-09-14 13:52:37.322621: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - 9s 69ms/step - loss: 0.2406 - accuracy: 0.9018 - val_loss: 0.1572 - val_accuracy: 0.9331
# Epoch 2/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.1099 - accuracy: 0.9613 - val_loss: 0.1701 - val_accuracy: 0.9302
# Epoch 3/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0708 - accuracy: 0.9762 - val_loss: 0.1259 - val_accuracy: 0.9500
# Epoch 4/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0613 - accuracy: 0.9786 - val_loss: 0.1116 - val_accuracy: 0.9566
# Epoch 5/20
# 121/121 [==============================] - 9s 70ms/step - loss: 0.0554 - accuracy: 0.9783 - val_loss: 0.1173 - val_accuracy: 0.9574
# Epoch 6/20
# 121/121 [==============================] - 9s 72ms/step - loss: 0.0457 - accuracy: 0.9827 - val_loss: 0.1081 - val_accuracy: 0.9611
# Epoch 7/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0373 - accuracy: 0.9879 - val_loss: 0.1094 - val_accuracy: 0.9625
# Epoch 8/20
# 121/121 [==============================] - 9s 69ms/step - loss: 0.0306 - accuracy: 0.9899 - val_loss: 0.1455 - val_accuracy: 0.9478
# Epoch 9/20
# 121/121 [==============================] - 9s 68ms/step - loss: 0.0216 - accuracy: 0.9925 - val_loss: 0.1253 - val_accuracy: 0.9611
# Epoch 10/20
# 121/121 [==============================] - 9s 69ms/step - loss: 0.0156 - accuracy: 0.9943 - val_loss: 0.1228 - val_accuracy: 0.9647
# Epoch 11/20
# 121/121 [==============================] - 9s 71ms/step - loss: 0.0090 - accuracy: 0.9972 - val_loss: 0.1272 - val_accuracy: 0.9655
# Epoch 11: early stopping

# %%
sigmoid_loss = hist4.history['loss']
sigmoid_accuracy = hist4.history['accuracy']
val_sigmoid_loss = hist4.history['val_loss']
val_sigmoid_accuracy = hist4.history['val_accuracy']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
sns.lineplot(x=hist4.epoch, y=sigmoid_loss, ax=ax1, label='loss')
sns.lineplot(x=hist4.epoch, y=sigmoid_accuracy, ax=ax2, label='accuracy')
sns.lineplot(x=hist4.epoch, y=val_sigmoid_loss, ax=ax1, label='val_loss')
sns.lineplot(x=hist4.epoch, y=val_sigmoid_accuracy, ax=ax2, label='val_accuracy')
plt.suptitle('Loss and Accuracy After Using Early Stopping', fontsize=20)
ax1.set_title('Model Loss with Early Stopping', fontsize=12)
ax2.set_title('Model Accuracy with Early Stopping', fontsize=12)
ax1.set_xlabel('Number of Epochs', loc='center', fontsize=12)
ax2.set_xlabel('Number of Epochs', loc='center', fontsize=12);

# %% [markdown]
# Changing to the early stopping callback led to the model only performing a few epochs - that likely isn't enough to provide a strong outcome given unseen data. I'm not going to include the early stopping callback in the final model, instead I'll use the original tensorboard callback for visualizations.

# %% [markdown]
# ## Regularization and additional Dense Layer

# %%
# Adding import of regularizer again to be safe

from tensorflow.keras.regularizers import l2

# %%
model5 = Sequential()

model5.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,1)))
model5.add(MaxPooling2D())
model5.add(Conv2D(32, (3,3), 1, activation='relu'))
model5.add(MaxPooling2D())
model5.add(Conv2D(16, (3,3), 1, activation='relu'))
model5.add(MaxPooling2D())
model5.add(Flatten())
model5.add(Dense(256, activation='relu', kernel_regularizer=l2(l=.05)))
model5.add(Dense(128, activation='relu', kernel_regularizer=l2(l=.05)))
model5.add(Dense(1, activation='sigmoid'))

adam = tf.keras.optimizers.Adam(learning_rate=0.0005)

model5.compile(optimizer=adam, loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

# %%
hist5 = model5.fit(train_data, epochs=20, batch_size=15, validation_data=val_data, callbacks=[tensorboard_callback])
# Out:
# Epoch 1/20
# 2022-09-14 13:54:06.558864: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - ETA: 0s - loss: 7.2786 - accuracy: 0.8380
# 2022-09-14 13:54:14.857861: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - 10s 78ms/step - loss: 7.2786 - accuracy: 0.8380 - val_loss: 2.1819 - val_accuracy: 0.9199
# Epoch 2/20
# 121/121 [==============================] - 11s 90ms/step - loss: 1.2125 - accuracy: 0.9370 - val_loss: 0.6573 - val_accuracy: 0.9295
# Epoch 3/20
# 121/121 [==============================] - 9s 73ms/step - loss: 0.4196 - accuracy: 0.9491 - val_loss: 0.3469 - val_accuracy: 0.9331
# Epoch 4/20
# 121/121 [==============================] - 9s 73ms/step - loss: 0.2347 - accuracy: 0.9589 - val_loss: 0.2483 - val_accuracy: 0.9353
# Epoch 5/20
# 121/121 [==============================] - 9s 71ms/step - loss: 0.1974 - accuracy: 0.9597 - val_loss: 0.2377 - val_accuracy: 0.9339
# Epoch 6/20
# 121/121 [==============================] - 9s 72ms/step - loss: 0.1779 - accuracy: 0.9675 - val_loss: 0.2166 - val_accuracy: 0.9420
# Epoch 7/20
# 121/121 [==============================] - 10s 84ms/step - loss: 0.1530 - accuracy: 0.9721 - val_loss: 0.1977 - val_accuracy: 0.9478
# Epoch 8/20
# 121/121 [==============================] - 11s 90ms/step - loss: 0.1612 - accuracy: 0.9687 - val_loss: 0.2058 - val_accuracy: 0.9471
# Epoch 9/20
# 121/121 [==============================] - 9s 71ms/step - loss: 0.1469 - accuracy: 0.9713 - val_loss: 0.1919 - val_accuracy: 0.9508
# Epoch 10/20
# 121/121 [==============================] - 10s 82ms/step - loss: 0.1263 - accuracy: 0.9783 - val_loss: 0.2629 - val_accuracy: 0.9206
# Epoch 11/20
# 121/121 [==============================] - 9s 70ms/step - loss: 0.1272 - accuracy: 0.9744 - val_loss: 0.1951 - val_accuracy: 0.9390
# Epoch 12/20
# 121/121 [==============================] - 9s 69ms/step - loss: 0.1326 - accuracy: 0.9726 - val_loss: 0.2983 - val_accuracy: 0.9184
# Epoch 13/20
# 121/121 [==============================] - 9s 69ms/step - loss: 0.1389 - accuracy: 0.9755 - val_loss: 0.1862 - val_accuracy: 0.9442
# Epoch 14/20
# 121/121 [==============================] - 9s 70ms/step - loss: 0.1283 - accuracy: 0.9768 - val_loss: 0.2274 - val_accuracy: 0.9317
# Epoch 15/20
# 121/121 [==============================] - 9s 69ms/step - loss: 0.1116 - accuracy: 0.9791 - val_loss: 0.1751 - val_accuracy: 0.9508
# Epoch 16/20
# 121/121 [==============================] - 9s 70ms/step - loss: 0.1142 - accuracy: 0.9765 - val_loss: 0.2456 - val_accuracy: 0.9265
# Epoch 17/20
# 121/121 [==============================] - 9s 70ms/step - loss: 0.1242 - accuracy: 0.9762 - val_loss: 0.1891 - val_accuracy: 0.9493
# Epoch 18/20
# 121/121 [==============================] - 9s 71ms/step - loss: 0.1140 - accuracy: 0.9804 - val_loss: 0.2855 - val_accuracy: 0.9214
# Epoch 19/20
# 121/121 [==============================] - 9s 69ms/step - loss: 0.1033 - accuracy: 0.9809 - val_loss: 0.2112 - val_accuracy: 0.9353
# Epoch 20/20
# 121/121 [==============================] - 9s 70ms/step - loss: 0.1055 - accuracy: 0.9804 - val_loss: 0.1988 - val_accuracy: 0.9449

# %%
sigmoid_loss = hist5.history['loss']
sigmoid_accuracy = hist5.history['accuracy']
val_sigmoid_loss = hist5.history['val_loss']
val_sigmoid_accuracy = hist5.history['val_accuracy']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
sns.lineplot(x=hist5.epoch, y=sigmoid_loss, ax=ax1, label='loss')
sns.lineplot(x=hist5.epoch, y=sigmoid_accuracy, ax=ax2, label='accuracy')
sns.lineplot(x=hist5.epoch, y=val_sigmoid_loss, ax=ax1, label='val_loss')
sns.lineplot(x=hist5.epoch, y=val_sigmoid_accuracy, ax=ax2, label='val_accuracy')
plt.suptitle('Loss and Accuracy With Regularization', fontsize=20)
ax1.set_title('Model Loss', fontsize=12)
ax2.set_title('Model Accuracy', fontsize=12)
ax1.set_xlabel('Number of Epochs', loc='center', fontsize=12)
ax2.set_xlabel('Number of Epochs', loc='center', fontsize=12);

# %%
model5.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_12 (Conv2D)          (None, 254, 254, 16)      160
#
#  max_pooling2d_12 (MaxPoolin  (None, 127, 127, 16)     0
#  g2D)
#
#  conv2d_13 (Conv2D)          (None, 125, 125, 32)      4640
#
#  max_pooling2d_13 (MaxPoolin  (None, 62, 62, 32)       0
#  g2D)
#
#  conv2d_14 (Conv2D)          (None, 60, 60, 16)        4624
#
#  max_pooling2d_14 (MaxPoolin  (None, 30, 30, 16)       0
#  g2D)
#
#  flatten_4 (Flatten)         (None, 14400)             0
#
#  dense_8 (Dense)             (None, 256)               3686656
#
#  dense_9 (Dense)             (None, 128)               32896
#
#  dense_10 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 3,729,105
# Trainable params: 3,729,105
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Overall, the issue of overfitting has been addressed, with the L2 Regularization removing the poor results on the validation data's log loss. With that said, the variability in accuracy for the validation data makes me think the model isn't done learning now at 20 epochs. In the next model I'm going to:
#
# - re-introduce early stopping
# - ramp up epochs to 40 to see how the model performs
# - change the L2 weight from .05 to .01
#
#
# I never added any dropout terms since the results are already pretty variable, and since my overfitting issue has mostly been addressed

# %%
#Adding Variable Callback again to be safe in order to set model class value for learning rate
import tensorflow.keras.backend as K

# %%
model6 = Sequential()

model6.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,1)))
model6.add(MaxPooling2D())
model6.add(Conv2D(32, (3,3), 1, activation='relu'))
model6.add(MaxPooling2D())
model6.add(Conv2D(16, (3,3), 1, activation='relu'))
model6.add(MaxPooling2D())
model6.add(Flatten())
model6.add(Dense(256, activation='relu', kernel_regularizer=l2(l=.01)))
model6.add(Dense(128, activation='relu', kernel_regularizer=l2(l=.01)))
model6.add(Dense(1, activation='sigmoid'))

model6.compile(optimizer='adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

#in order to add multiple callbacks, need to set learning rate via Keras
K.set_value(model6.optimizer.lr, 5e-4)

# %%
hist6 = model6.fit(train_data, epochs=40, batch_size=15, validation_data=val_data, callbacks=[tensorboard_callback, early_stop])
# Out:
# Epoch 1/40
# 2022-09-14 13:57:13.273772: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - ETA: 0s - loss: 1.9573 - accuracy: 0.8396
# 2022-09-14 13:57:20.790624: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - 9s 71ms/step - loss: 1.9573 - accuracy: 0.8396 - val_loss: 0.8288 - val_accuracy: 0.8979
# Epoch 2/40
# 121/121 [==============================] - 9s 70ms/step - loss: 0.4716 - accuracy: 0.9522 - val_loss: 0.4375 - val_accuracy: 0.9221
# Epoch 3/40
# 121/121 [==============================] - 9s 70ms/step - loss: 0.2794 - accuracy: 0.9615 - val_loss: 0.2798 - val_accuracy: 0.9405
# Epoch 4/40
# 121/121 [==============================] - 9s 70ms/step - loss: 0.2241 - accuracy: 0.9636 - val_loss: 0.2394 - val_accuracy: 0.9420
# Epoch 5/40
# 121/121 [==============================] - 9s 70ms/step - loss: 0.1709 - accuracy: 0.9708 - val_loss: 0.3473 - val_accuracy: 0.8949
# Epoch 6/40
# 121/121 [==============================] - 9s 70ms/step - loss: 0.1673 - accuracy: 0.9638 - val_loss: 0.2163 - val_accuracy: 0.9456
# Epoch 27/40
# 121/121 [==============================] - 9s 70ms/step - loss: 0.0526 - accuracy: 0.9915 - val_loss: 0.2201 - val_accuracy: 0.9405
# Epoch 28/40
# 121/121 [==============================] - 9s 70ms/step - loss: 0.0660 - accuracy: 0.9861 - val_loss: 0.2568 - val_accuracy: 0.9273
# Epoch 28: early stopping

# %%
sigmoid_loss = hist6.history['loss']
sigmoid_accuracy = hist6.history['accuracy']
val_sigmoid_loss = hist6.history['val_loss']
val_sigmoid_accuracy = hist6.history['val_accuracy']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
sns.lineplot(x=hist6.epoch, y=sigmoid_loss, ax=ax1, label='loss')
sns.lineplot(x=hist6.epoch, y=sigmoid_accuracy, ax=ax2, label='accuracy')
sns.lineplot(x=hist6.epoch, y=val_sigmoid_loss, ax=ax1, label='val_loss')
sns.lineplot(x=hist6.epoch, y=val_sigmoid_accuracy, ax=ax2, label='val_accuracy')
plt.suptitle('Loss and Accuracy With Final Regularization', fontsize=20)
ax1.set_title('Model Loss', fontsize=12)
ax2.set_title('Model Accuracy', fontsize=12)
ax1.set_xlabel('Number of Epochs', loc='center', fontsize=12)
ax2.set_xlabel('Number of Epochs', loc='center', fontsize=12);

# %% [markdown]
# # Final Model
#
# Below is the final model we intend to share with the Gates Foundation for implementation

# %%
# Update so that both training and validation data is used to fit final model for evaluation on test data

final_train_data = tf.keras.utils.image_dataset_from_directory('../Data/CellData/chest_xray/total_train/',
                                                               color_mode='grayscale',
                                                               label_mode='binary')

test_data = tf.keras.utils.image_dataset_from_directory('../Data/CellData/chest_xray/test/',
                                                        color_mode='grayscale',
                                                        label_mode='binary')
# Out:
# Found 5232 files belonging to 2 classes.
# Found 624 files belonging to 2 classes.

# %%
# updating to evaluate against validation accuracy and patience in early stopping in order to better generate model
early_stop2 = EarlyStopping(monitor='val_loss', min_delta=1e-10,
                           verbose=1,
                           mode='min',
                           patience=7)

# %%
final_model = Sequential()

final_model.add(Conv2D(16, (3,3), 1, activation='relu', input_shape=(256,256,1)))
final_model.add(MaxPooling2D())
final_model.add(Conv2D(32, (3,3), 1, activation='relu'))
final_model.add(MaxPooling2D())
final_model.add(Conv2D(16, (3,3), 1, activation='relu'))
final_model.add(MaxPooling2D())
final_model.add(Flatten())
final_model.add(Dense(256, activation='relu', kernel_regularizer=l2(l=.01)))
final_model.add(Dense(128, activation='relu', kernel_regularizer=l2(l=.01)))
final_model.add(Dense(64, activation='relu'))
final_model.add(Dense(1, activation='sigmoid'))

final_model.compile(optimizer='adam', loss=tf.losses.BinaryCrossentropy(), metrics=['accuracy'])

#in order to add multiple callbacks, need to set learning rate via Keras
K.set_value(final_model.optimizer.lr, 5e-4)

# %%
final_model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_48 (Conv2D)          (None, 254, 254, 16)      160
#
#  max_pooling2d_48 (MaxPoolin  (None, 127, 127, 16)     0
#  g2D)
#
#  conv2d_49 (Conv2D)          (None, 125, 125, 32)      4640
#
#  max_pooling2d_49 (MaxPoolin  (None, 62, 62, 32)       0
#  g2D)
#
#  conv2d_50 (Conv2D)          (None, 60, 60, 16)        4624
#
#  max_pooling2d_50 (MaxPoolin  (None, 30, 30, 16)       0
#  g2D)
#
#  flatten_16 (Flatten)        (None, 14400)             0
#
#  dense_47 (Dense)            (None, 256)               3686656
#
#  dense_48 (Dense)            (None, 128)               32896
#
#  dense_49 (Dense)            (None, 64)                8256
#
#  dense_50 (Dense)            (None, 1)                 65
#
# =================================================================
# Total params:
# Epoch 18/40
# 164/164 [==============================] - 11s 62ms/step - loss: 0.2326 - accuracy: 0.9895 - val_loss: 1.2293 - val_accuracy: 0.8349
# Epoch 19/40
# 164/164 [==============================] - 11s 63ms/step - loss: 0.2038 - accuracy: 0.9925 - val_loss: 1.9139 - val_accuracy: 0.7949
# Epoch 20/40
# 164/164 [==============================] - 11s 62ms/step - loss: 0.1713 - accuracy: 0.9964 - val_loss: 1.9511 - val_accuracy: 0.7788
# Epoch 21/40
# 164/164 [==============================] - 11s 62ms/step - loss: 0.1598 - accuracy: 0.9941 - val_loss: 1.9412 - val_accuracy: 0.8093
# Epoch 21: early stopping

# %%
sigmoid_loss = final_hist.history['loss']
sigmoid_accuracy = final_hist.history['accuracy']
val_sigmoid_loss = final_hist.history['val_loss']
val_sigmoid_accuracy = final_hist.history['val_accuracy']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
sns.lineplot(x=final_hist.epoch, y=sigmoid_loss, ax=ax1, color='r', label='training loss')
sns.lineplot(x=final_hist.epoch, y=sigmoid_accuracy, ax=ax2, color='r', label='training accuracy')
sns.lineplot(x=final_hist.epoch, y=val_sigmoid_loss, ax=ax1, color='b', label='training loss')
sns.lineplot(x=final_hist.epoch, y=val_sigmoid_accuracy, ax=ax2, color='b', label='training accuracy')
plt.suptitle('Loss and Accuracy With Final Regularization', fontsize=20)
ax1.set_title('Model Loss', fontsize=12)
ax2.set_title('Model Accuracy', fontsize=12)
ax1.set_xlabel('Number of Epochs', loc='center', fontsize=12)
ax2.set_xlabel('Number of Epochs', loc='center', fontsize=12);

# %%
#evaluate with validation data

hist7 = final_model.fit(train_data, epochs=40, batch_size=15, validation_data=val_data, callbacks=[tensorboard_callback, early_stop2])
# Out:
# Epoch 1/40
# 2022-09-14 16:13:13.171656: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - ETA: 0s - loss: 0.4440 - accuracy: 0.8825
# 2022-09-14 16:13:21.024709: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 121/121 [==============================] - 10s 73ms/step - loss: 0.4440 - accuracy: 0.8825 - val_loss: 0.4549 - val_accuracy: 0.8707
# Epoch 2/40
# 121/121 [==============================] - 9s 70ms/step - loss: 0.2862 - accuracy: 0.9452 - val_loss: 0.3219 - val_accuracy: 0.9236
# Epoch 3/40
# 121/121 [==============================] - 9s 70ms/step - loss: 0.2401 - accuracy: 0.9569 - val_loss: 0.2753 - val_accuracy: 0.9420
# Epoch 4/40
# 121/121 [==============================] - 9s 69ms/step - loss: 0.2057 - accuracy: 0.9708 - val_loss: 0.2212 - val_accuracy: 0.9544
# Epoch 5/40
# 121/121 [==============================] - 9s 69ms/step - loss: 0.1890 - accuracy: 0.9711 - val_loss: 0.2113 - val_accuracy: 0.9559
# Epoch 6/40
# 121/121 [==============================] - 9s 69ms/step - loss: 0.1935 - accuracy: 0.9659 - val_loss: 0.3486 - val_accuracy: 0.9052
# Epoch 7/40
# 121/121 [==============================] - 9s 69ms/step - loss: 0.1606 - accuracy: 0.9775 - val_loss: 0.2702 - val_accuracy: 0.9280
# Epoch 8/40
# 121/121 [==============================] - 9s 69ms/step - loss: 0.1441 - accuracy: 0.9793 - val_loss: 0.1824 - val_accuracy: 0.9552
# Epoch 29/40
# 121/121 [==============================] - 9s 69ms/step - loss: 0.0360 - accuracy: 0.9982 - val_loss: 0.1418 - val_accuracy: 0.9611
# Epoch 30/40
# 121/121 [==============================] - 9s 70ms/step - loss: 0.0339 - accuracy: 0.9987 - val_loss: 0.1440 - val_accuracy: 0.9662
# Epoch 31/40
# 121/121 [==============================] - 9s 70ms/step - loss: 0.0442 - accuracy: 0.9930 - val_loss: 0.1531 - val_accuracy: 0.9544
# Epoch 32/40
# 121/121 [==============================] - 9s 70ms/step - loss: 0.0592 - accuracy: 0.9902 - val_loss: 0.1425 - val_accuracy: 0.9647
# Epoch 32: early stopping

# %%
sigmoid_loss = hist7.history['loss']
sigmoid_accuracy = hist7.history['accuracy']
val_sigmoid_loss = hist7.history['val_loss']
val_sigmoid_accuracy = hist7.history['val_accuracy']

fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 10))
sns.lineplot(x=hist7.epoch, y=sigmoid_loss, ax=ax1, label='loss')
sns.lineplot(x=hist7.epoch, y=sigmoid_accuracy, ax=ax2, label='accuracy')
sns.lineplot(x=hist7.epoch, y=val_sigmoid_loss, ax=ax1, label='val_loss')
sns.lineplot(x=hist7.epoch, y=val_sigmoid_accuracy, ax=ax2, label='val_accuracy')
plt.suptitle('Final Model Performance on Train and Validation Data', fontsize=20)
ax1.set_title('Model Loss', fontsize=12)
ax2.set_title('Model Accuracy', fontsize=12)
ax1.set_xlabel('Number of Epochs', loc='center', fontsize=12)
ax2.set_xlabel('Number of Epochs', loc='center', fontsize=12);

# %% [markdown]
# # Final Model Evaluation

# %%
from tensorflow.keras.metrics import Precision, Recall, BinaryAccuracy

# %%
pre = Precision()
re = Recall()
acc = BinaryAccuracy()

# %%
for batch in test_data.as_numpy_iterator(): 
    X, y = batch
    yhat = final_model.predict(X)
    pre.update_state(y, yhat)
    re.update_state(y, yhat)
    acc.update_state(y, yhat)
# Out:
# 1/1 [==============================] - 0s 85ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 2022-09-14 16:17:52.844210: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 14ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 11ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 12ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 10ms/step
# 1/1 [==============================] - 0s 80ms/step
# 2022-09-14 16:17:53.928401: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:113] Plugin optimizer for device_type GPU is enabled.

# %%
print('final model precision on test data is:', pre.result(), '\n')
print('final model recall on test data is:', re.result(), '\n') 
print('final model accuracy on test data is:', acc.result(), '\n')
# Out:
# final model precision on test data is: tf.Tensor(0.855792, shape=(), dtype=float32)
#
# final model recall on test data is: tf.Tensor(0.92820513, shape=(), dtype=float32)
#
# final model accuracy on test data is: tf.Tensor(0.8573718, shape=(), dtype=float32)

# %% [markdown]
# # Pickling Model For Use

# %%
# import joblib

# # use the built-in open() function to open a file
# output_file = open("predict_pneumonia.pkl", "wb") # "wb" means "write as bytes"
# # dump the variable's contents into the file
# joblib.dump(final_model, output_file)
# # close the file, ensuring nothing stays in the buffer
# output_file.close()

# %% [markdown]
# # Summary

# %% [markdown]
# Summary elements:
#
# Business and data understanding: what kind of data are you using, and what makes it well-suited for the business problem?
# You do not need to include any data visualizations in your summary, but consider including relevant descriptive statistics
# Data preparation: why did you choose the data preparation steps that you did, and what was the result?
# This should be specific to the kind of data you are working with. For example, if you are doing an NLP project, what did you decide to do with stopwords?
# Be sure to list the packages/libraries used to prepare the data, and why
# Modeling: what modeling package(s) did you use, which model(s) within the package(s), and what tuning steps did you take?
# For some projects there may be only one applicable package; you should still briefly explain why this was the appropriate choice
# For neural networks projects, be sure to describe your model architecture choices
# Evaluation: how well did your final model perform?
# Include one or more relevant metrics
# Be sure to briefly describe your validation approach
